# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
sns.set_style("darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight') 
import warnings
warnings.filterwarnings('ignore')

# %%
confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/26/21  4/27/21  4/28/21  \
# 0        0        0        0        0  ...    59015    59225    59370
# 1        0        0        0        0  ...   130606   130736   130859
# 2        0        0        0        0  ...   121112   121344   121580
# 3        0        0        0        0  ...    13083    13121    13148
# 4        0        0        0        0  ...    25710    25942    26168
#
#    4/29/21  4/30/21  5/1/21  5/2/21  5/3/21  5/4/21  5/5/21
# ...

# %%
country = confirmed.groupby('Country/Region')

# %%
country.get_group('Nigeria')
# Out:
#     Province/State Country/Region    Lat    Long  1/22/20  1/23/20  1/24/20  \
# 200            NaN        Nigeria  9.082  8.6753        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  4/26/21  4/27/21  4/28/21  4/29/21  \
# 200        0        0        0  ...   164756   164912   164993   165055
#
#      4/30/21  5/1/21  5/2/21  5/3/21  5/4/21  5/5/21
# 200   165110  165110  165153  165199  165215  165273
#
# [1 rows x 474 columns]

# %%
recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
recovered.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/26/21  4/27/21  4/28/21  \
# 0        0        0        0        0  ...    52520    52794    52974
# 1        0        0        0        0  ...   106465   107163   107887
# 2        0        0        0        0  ...    84440    84598    84745
# 3        0        0        0        0  ...    12519    12561    12590
# 4        0        0        0        0  ...    23288    23341    23584
#
#    4/29/21  4/30/21  5/1/21  5/2/21  5/3/21  5/4/21  5/5/21
# ...

# %%
death = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

# %%
death.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/26/21  4/27/21  4/28/21  \
# 0        0        0        0        0  ...     2592     2598     2611
# 1        0        0        0        0  ...     2379     2383     2386
# 2        0        0        0        0  ...     3217     3225     3234
# 3        0        0        0        0  ...      124      124      125
# 4        0        0        0        0  ...      583      587      591
#
#    4/29/21  4/30/21  5/1/21  5/2/21  5/3/21  5/4/21  5/5/21
# ...

# %%
death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Columns: 474 entries, Province/State to 5/5/21
# dtypes: float64(2), int64(470), object(2)
# memory usage: 1018.5+ KB

# %%
country2 = death.groupby('Country/Region')

# %%
country2.get_group('Nigeria')
# Out:
#     Province/State Country/Region    Lat    Long  1/22/20  1/23/20  1/24/20  \
# 200            NaN        Nigeria  9.082  8.6753        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  4/26/21  4/27/21  4/28/21  4/29/21  \
# 200        0        0        0  ...     2062     2063     2063     2063
#
#      4/30/21  5/1/21  5/2/21  5/3/21  5/4/21  5/5/21
# 200     2063    2063    2063    2063    2063    2065
#
# [1 rows x 474 columns]

# %%
nigeria = pd.read_csv('covidnig.csv')

# %%
nigeria['No. Discharged'] = nigeria['No. Discharged'].str.replace(',', '').astype(int)

# %%
nigeria['No. of Cases (on admission)'] = nigeria['No. of Cases (on admission)'].str.replace(',', '').astype(int)

# %%
nigeria['No. of Cases (Lab Confirmed)'] = nigeria['No. of Cases (Lab Confirmed)'].str.replace(',', '').astype(int)

# %%
nigeria.head()
# Out:
#   States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0           Lagos                         26708                         2435
# 1             FCT                          9627                         2840
# 2          Kaduna                          4504                          579
# 3         Plateau                          4262                          280
# 4             Oyo                          3788                          368
#
#    No. Discharged  No. of Deaths
# 0           24037            236
# 1            6694             93
# 2            3877             48
# 3            3948             34
# 4            3374             46

# %%
no_confirmed = nigeria[['States Affected', 'No. of Cases (Lab Confirmed)']]

# %%
no_confirmed.head()
# Out:
#   States Affected  No. of Cases (Lab Confirmed)
# 0           Lagos                         26708
# 1             FCT                          9627
# 2          Kaduna                          4504
# 3         Plateau                          4262
# 4             Oyo                          3788

# %%
no_confirmed2 = no_confirmed.nlargest(10, 'No. of Cases (Lab Confirmed)')

# %%
no_confirmed2
# Out:
#   States Affected  No. of Cases (Lab Confirmed)
# 0           Lagos                         26708
# 1             FCT                          9627
# 2          Kaduna                          4504
# 3         Plateau                          4262
# 4             Oyo                          3788
# 5          Rivers                          3279
# 6             Edo                          2768
# 7            Ogun                          2382
# 8            Kano                          2032
# 9           Delta                          1843

# %%
no_confirmed2.plot.bar(x='States Affected', y='No. of Cases (Lab Confirmed)')
plt.ylabel('No. of Cases(Lab Confirmed)', size = 20)
plt.title('Top ten states in terms of Confirmed cases', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
nig2 = nigeria[['States Affected', 'No. of Cases (on admission)']]

# %%
nig3 = nig2.nlargest(10, 'No. of Cases (on admission)')

# %%
nig3
# Out:
#    States Affected  No. of Cases (on admission)
# 1              FCT                         2840
# 0            Lagos                         2435
# 2           Kaduna                          579
# 4              Oyo                          368
# 3          Plateau                          280
# 21        Nasarawa                          262
# 5           Rivers                          232
# 11         Katsina                          214
# 8             Kano                          198
# 14           Gombe                          183

# %%
nig3.plot.bar(x='States Affected', y='No. of Cases (on admission)')
# Out:
# <AxesSubplot:xlabel='States Affected'>

# %%
no_discharged = nigeria[['States Affected', 'No. Discharged']]

# %%
no_discharged2 = no_discharged.nlargest(10, 'No. Discharged')

# %%
no_discharged2
# Out:
#   States Affected  No. Discharged
# 0           Lagos           24037
# 1             FCT            6694
# 3         Plateau            3948
# 2          Kaduna            3877
# 4             Oyo            3374
# 5          Rivers            2987
# 6             Edo            2603
# 7            Ogun            2175
# 8            Kano            1778
# 9           Delta            1737

# %%
no_discharged2.plot.bar(x='States Affected', y='No. Discharged')
plt.ylabel('No. Discharged', size = 20)
plt.title('Top ten states in terms of Discharged Covid cases', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
no_of_death = nigeria[['States Affected', 'No. of Deaths']]

# %%
no_of_death2 = no_of_death.nlargest(10, 'No. of Deaths')

# %%
no_of_death2
# Out:
#    States Affected  No. of Deaths
# 0            Lagos            236
# 6              Edo            113
# 1              FCT             93
# 5           Rivers             60
# 8             Kano             56
# 9            Delta             49
# 2           Kaduna             48
# 4              Oyo             46
# 10            Ondo             41
# 19           Borno             36

# %%
no_of_death2.plot.bar(x='States Affected', y='No. of Deaths')
plt.ylabel('No. of Deaths', size = 20)
plt.title('Top ten states in terms of Covid Death cases', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
nigeria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int32
#  2   No. of Cases (on admission)   37 non-null     int32
#  3   No. Discharged                37 non-null     int32
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int32(3), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
Budget = pd.read_csv('Budget data.csv')

# %%
Budget.head()
# Out:
#       states  Initial_budget (Bn)  Revised_budget (Bn)
# 0       Abia               136.60               102.70
# 1    Adamawa               183.30               139.31
# 2  Akwa-Ibom               597.73               366.00
# 3    Anambra               137.10               112.80
# 4     Bauchi               167.20               128.00

# %%
Budget.plot.bar(x='states', y='Initial_budget (Bn)')
plt.ylabel('Initial_budget(Bn)', size = 20)
plt.title('Initial Budget per State', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
Budget.plot.bar(x='states', y='Revised_budget (Bn)')
plt.ylabel('Revised_budget (Bn)', size = 20)
plt.title('Revised Budget per State', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
External = pd.read_csv('covid_external.csv')

# %%
External.head()
# Out:
#       states         region  Population  Overall CCVI Index  Age  \
# 0        FCT  North Central     4865000                 0.3  0.0
# 1    Plateau  North Central     4766000                 0.4  0.5
# 2      Kwara  North Central     3524000                 0.3  0.4
# 3  Nassarawa  North Central     2783000                 0.1  0.3
# 4      Niger  North Central     6260000                 0.6  0.0
#
#    Epidemiological  Fragility  Health System  Population Density  \
# 0              0.9        0.4            0.6                 0.9
# 1              0.4        0.8            0.3                 0.3
# 2              0.3        0.2            0.4                 0.2
# 3              0.5        0.9            0.0                 0.1
# 4              0.6        0.3            0.7                 0.1
#
#    Socio-Economic   Transport Availability  Acute IHR
# 0             0.6                      0.2       0.79
# 1             0.5                      0.3       0.93
# ...

# %%
External.rename({'states': 'States Affected'}, axis=1, inplace=True)

# %%
External.head()
# Out:
#   States Affected         region  Population  Overall CCVI Index  Age  \
# 0             FCT  North Central     4865000                 0.3  0.0
# 1         Plateau  North Central     4766000                 0.4  0.5
# 2           Kwara  North Central     3524000                 0.3  0.4
# 3       Nassarawa  North Central     2783000                 0.1  0.3
# 4           Niger  North Central     6260000                 0.6  0.0
#
#    Epidemiological  Fragility  Health System  Population Density  \
# 0              0.9        0.4            0.6                 0.9
# 1              0.4        0.8            0.3                 0.3
# 2              0.3        0.2            0.4                 0.2
# 3              0.5        0.9            0.0                 0.1
# 4              0.6        0.3            0.7                 0.1
#
#    Socio-Economic   Transport Availability  Acute IHR
# 0             0.6                      0.2       0.79
# ...

# %%
GDP = pd.read_csv('RealGDP.csv')

# %%
GDP
# Out:
#    Year           Q1           Q2           Q3           Q4
# 0  2014  15438679.50  16084622.31  17479127.58  18150356.45
# 1  2015  16050601.38  16463341.91  17976234.59  18533752.07
# 2  2016  15943714.54  16218542.41  17555441.69  18213537.29
# 3  2017  15797965.83  16334719.27  17760228.17  18598067.07
# 4  2018  16096654.19  16580508.07  18081342.10  19041437.59
# 5  2019  16434552.65  16931434.89  18494114.17  19530000.00
# 6  2020  16740000.00  15890000.00  17820000.00         0.00

# %%
GDP1 = pd.melt(GDP, id_vars=['Year'], value_vars='Q1', ignore_index=False)

# %%
GDP1
# Out:
#    Year variable        value
# 0  2014       Q1  15438679.50
# 1  2015       Q1  16050601.38
# 2  2016       Q1  15943714.54
# 3  2017       Q1  15797965.83
# 4  2018       Q1  16096654.19
# 5  2019       Q1  16434552.65
# 6  2020       Q1  16740000.00

# %%
sns.catplot(x='Year', y='value', data=GDP1, aspect=2, kind='point')
plt.ylabel('Real GDP', size = 20)
plt.title('Real GDP for Ist Quarter', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
GDP2 = pd.melt(GDP, id_vars=['Year'], value_vars='Q2', ignore_index=False)

# %%
sns.catplot(x='Year', y='value', data=GDP2, aspect=2, kind='point')
plt.ylabel('Real GDP', size = 20)
plt.title('Real GDP for 2nd Quarter', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
GDP3 = pd.melt(GDP, id_vars=['Year'], value_vars='Q3', ignore_index=False)

# %%
sns.catplot(x='Year', y='value', data=GDP3, aspect=2, kind='point')
plt.ylabel('Real GDP', size = 20)
plt.title('Real GDP for 3rd Quarter', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
GDP4 = pd.melt(GDP, id_vars=['Year'], value_vars='Q4', ignore_index=False)

# %%
sns.catplot(x='Year', y='value', data=GDP4, aspect=2, kind='point')
plt.ylabel('Real GDP', size = 20)
plt.title('Real GDP for 4th Quarter', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
nigeria_external = pd.merge(nigeria, External, on='States Affected')

# %%
nigeria_external.head()
# Out:
#   States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0           Lagos                         26708                         2435
# 1             FCT                          9627                         2840
# 2          Kaduna                          4504                          579
# 3         Plateau                          4262                          280
# 4             Oyo                          3788                          368
#
#    No. Discharged  No. of Deaths         region  Population  \
# 0           24037            236     South West    13992000
# 1            6694             93  North Central     4865000
# 2            3877             48     North West     9227000
# 3            3948             34  North Central     4766000
# 4            3374             46     South West     8737000
#
#    Overall CCVI Index  Age  Epidemiological  Fragility  Health System  \
# ...

# %%
nigeria_external.plot.bar(x='States Affected', y='Health System')
plt.ylabel('Health System', size = 20)
plt.title('Health System Index for each State', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
nigeria_external.plot.bar(x='States Affected', y='No of Cases (on admission)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'No of Cases (on admission)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-137b18e1e578> in <module>
# ...

# %%
nigeria_external.plot.bar(x='States Affected', y='Fragility')
plt.ylabel('Fragility', size = 20)
plt.title('Fragility Index for each state', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
nigeria_external.plot.bar(x='States Affected', y='Population Density')
plt.ylabel('Population Density', size = 20)
plt.title('Population Density of each State', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
nigeria_external.plot.bar(x='States Affected', y='Overall CCVI Index')
plt.ylabel('Overall CCVI Index', size = 20)
plt.title('Overall CCVI Index of each State', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
nigeria_external.plot.bar(x='States Affected', y='Epidemiological')
plt.ylabel('Epidemiological Index', size = 20)
plt.title('Epidemiological Index of each State', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
nigeria_external.plot.bar(x='States Affected', y='Acute IHR')
plt.ylabel('Acute IHR Index', size = 20)
plt.title('Acute IHR Index of each State', size=24)
plt.subplots(facecolor='w')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)
